# %% [markdown]
# # Python Pandas

# %%
import pandas as pd

# %%
demo=pd.read_csv("/content/sample_data/pokemon.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-6-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %%
demo.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
demo.to_excel("pokemon.xlsx")

# %% [markdown]
# # Reading Data

# %%
demo.columns #read every header
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
demo[["Name","Legendary"]] #read specific header
# Out:
#                       Name  Legendary
# 0                Bulbasaur      False
# 1                  Ivysaur      False
# 2                 Venusaur      False
# 3    VenusaurMega Venusaur      False
# 4               Charmander      False
# ..                     ...        ...
# 795                Diancie       True
# 796    DiancieMega Diancie       True
# 797    HoopaHoopa Confined       True
# 798     HoopaHoopa Unbound       True
# 799              Volcanion       True
#
# [800 rows x 2 columns]

# %%
demo["Name"][0:3]
# Out:
# 0    Bulbasaur
# 1      Ivysaur
# 2     Venusaur
# Name: Name, dtype: object

# %%
demo.iloc[1:3] #read each row
# Out:
#    #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 1  2   Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3  Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 1           1      False
# 2           1      False

# %%
demo.iloc[2,1] #column with position i.e first position and second index
# Out:
# 'Venusaur'

# %%
demo.loc[demo["Name"]=="Venusaur"]
# Out:
#    #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 2  3  Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 2           1      False

# %%
demo.loc[demo["Type 1"]=="Grass"]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# # Sorting/Describe

# %%
demo.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
demo.sort_values("Name", ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f4de502f6a92> in <cell line: 1>()
# ----> 1 demo.sort_values("Name", ascending=False)
#
# NameError: name 'demo' is not defined

# %%
demo.sort_values(["Type 1","HP"])
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 351  321    Wailord  Water     NaN  170      90       45       90       45
#
#      Speed  Generation  Legendary
# ...

# %% [markdown]
# # Making Changes to Data

# %%
demo.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
demo["Total"]=demo["HP"] + demo["Attack"] + demo["Defense"] + demo["Sp. Atk"] + demo["Sp. Def"] + demo["Speed"]

# %%
demo.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
res=demo.sort_values(["Total"], ascending=True)
res.head(5)
# Out:
#        #       Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 206  191    Sunkern   Grass     NaN  30      30       30       30       30
# 322  298    Azurill  Normal   Fairy  50      20       40       20       40
# 446  401  Kricketot     Bug     NaN  37      25       41       25       41
# 288  265    Wurmple     Bug     NaN  45      45       35       20       30
# 16    13     Weedle     Bug  Poison  40      35       30       20       20
#
#      Speed  Generation  Legendary  Total
# 206     30           2      False    180
# 322     20           3      False    190
# 446     25           4      False    194
# 288     20           3      False    195
# 16      50           1      False    195

# %%
cols=list(demo.columns)
cols
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
new=demo[cols[0:4] + [cols[-1]] + cols[4:12]]
new
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
res=res.drop(columns="Total")
res
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 206  191                Sunkern    Grass       NaN   30      30       30
# 322  298                Azurill   Normal     Fairy   50      20       40
# 446  401              Kricketot      Bug       NaN   37      25       41
# 288  265                Wurmple      Bug       NaN   45      45       35
# 16    13                 Weedle      Bug    Poison   40      35       30
# ..   ...                    ...      ...       ...  ...     ...      ...
# 424  383  GroudonPrimal Groudon   Ground      Fire  100     180      160
# 422  382    KyogrePrimal Kyogre    Water       NaN  100     150       90
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 426  384  RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
demo.loc[(demo["Type 1"]=="Grass") & (demo["Type 2"]=="Poison")]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
demo.loc[demo["Type 1"]=="Bug"]
# Out:
#        #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 13    10    Caterpie    Bug     NaN  45      30       35       20       20
# 14    11     Metapod    Bug     NaN  50      20       55       25       25
# 15    12  Butterfree    Bug  Flying  60      45       50       90       80
# 16    13      Weedle    Bug  Poison  40      35       30       20       20
# 17    14      Kakuna    Bug  Poison  45      25       50       25       25
# ..   ...         ...    ...     ...  ..     ...      ...      ...      ...
# 698  637   Volcarona    Bug    Fire  85      60       65      135      105
# 717  649    Genesect    Bug   Steel  71     120       95      120       95
# 732  664  Scatterbug    Bug     NaN  38      35       40       27       25
# 733  665      Spewpa    Bug     NaN  45      22       60       27       30
# 734  666    Vivillon    Bug  Flying  80      52       50       90       50
#
#      Speed  Generation  Legendary
# ...

# %%
demo.loc[~demo["Type 1"].str.contains("Bug")]
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
import re

demo.loc[demo["Type 1"].str.contains("Grass|Rock", regex=True)]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 768  698                 Amaura   Rock     Ice   77      59       50       67
# 769  699                Aurorus   Rock     Ice  123      77       72       99
# 773  703                Carbink   Rock   Fairy   50      50      150       50
# 795  719                Diancie   Rock   Fairy   50     100      150      100
# 796  719    DiancieMega Diancie   Rock   Fairy   50     160      110      160
#
# ...

# %%
demo.loc[demo["Name"].str.contains("Di[a-z]*", regex=True)]
# Out:
#        #                 Name  Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 55    50              Diglett  Ground     NaN   10      55       25       35
# 143  132                Ditto  Normal     NaN   48      48       48       48
# 540  483               Dialga   Steel  Dragon  100     120      120      150
# 728  660            Diggersby  Normal  Ground   85      56       77       50
# 795  719              Diancie    Rock   Fairy   50     100      150      100
# 796  719  DiancieMega Diancie    Rock   Fairy   50     160      110      160
#
#      Sp. Def  Speed  Generation  Legendary
# 55        45     95           1      False
# 143       48     48           1      False
# 540      100     90           4       True
# 728       77     78           6      False
# 795      150     50           6       True
# 796      110    110           6       True
